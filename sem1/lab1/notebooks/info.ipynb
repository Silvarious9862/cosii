# %%
import sys
sys.path.append('../src')

import numpy as np
import matplotlib.pyplot as plt

from signals import generate_signal, read_signal
from fft_time_decimation import fft_dit, ifft_dit
from convolution import conv_time, conv_fft
from correlation import corr_time, corr_fft

# %%
generate_signal?
# Out:
# Signature:
# generate_signal(
#     name: str,
#     func: Callable[[numpy.ndarray], numpy.ndarray],
#     fs: int = 44100,
#     duration: float = 3.0,
# )
# Docstring:
# name  – имя WAV-файла
# func  – функция сигнала: принимает массив t, возвращает массив s(t)
# fs    – частота дискретизации
# duration – длительность в секундах
# пример вызова:
# generate_signal('sig1.wav', lambda t: 2*np.sin(3*t) + np.cos(2*t + 1))
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\signals.py
# Type:      function

# %%
read_signal?
# Out:
# Signature: read_signal(name: str)
# Docstring:
# пример вызова:
# fs1, x_list = read_signal('sig1.wav')
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\signals.py
# Type:      function

# %%
fft_dit?
# Out:
# Signature: fft_dit(x: List[complex], inverse: bool = False) -> List[complex]
# Docstring:
# БПФ с прореживанием по времени (Decimation In Time).
# x: список комплексных отсчётов, длина N=2^k.
# inverse=True вычисляет обратное БПФ.
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\fft_time_decimation.py
# Type:      function

# %%
ifft_dit?
# Out:
# Signature: ifft_dit(X: List[complex]) -> List[complex]
# Docstring: <no docstring>
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\fft_time_decimation.py
# Type:      function

# %%
ifft_dit?
# Out:
# Signature: ifft_dit(X: List[complex]) -> List[complex]
# Docstring: <no docstring>
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\fft_time_decimation.py
# Type:      function

# %%
conv_time?
# Out:
# Signature: conv_time(x: List[complex], y: List[complex]) -> List[complex]
# Docstring:
# Свёртка по определению во временной области.
# Длины: len(x) = N, len(y) = M, результат длины N+M-1.
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\convolution.py
# Type:      function

# %%
conv_fft?
# Out:
# Signature: conv_fft(x: List[complex], y: List[complex]) -> List[complex]
# Docstring: Свёртка с использованием БПФ_В.
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\convolution.py
# Type:      function

# %%
corr_time?
# Out:
# Signature: corr_time(x: List[complex], y: List[complex]) -> List[complex]
# Docstring: Корреляция по определению во временной области.
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\correlation.py
# Type:      function

# %%
corr_fft?
# Out:
# Signature: corr_fft(x: List[complex], y: List[complex]) -> List[complex]
# Docstring: Корреляция через БПФ по теореме корреляции.
# File:      e:\docs\bsuir\cosii\sem1\lab1\src\correlation.py
# Type:      function
